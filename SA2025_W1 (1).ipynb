# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here

df = pd.read_csv('Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.set_index('name', inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
df['mpg'].unique().tolist()
# Out:
# [18.0,
#  15.0,
#  16.0,
#  17.0,
#  14.0,
#  24.0,
#  22.0,
#  21.0,
#  27.0,
#  26.0,
#  25.0,
#  10.0,
#  11.0,
#  9.0,
#  28.0,
#  19.0,
#  12.0,
#  13.0,
#  23.0,
#  30.0,
#  31.0,
#  35.0,
#  20.0,
#  29.0,
#  32.0,
#  33.0,
#  17.5,
#  15.5,
#  14.5,
#  22.5,
#  24.5,
#  18.5,
#  29.5,
#  26.5,
#  16.5,
#  31.5,
#  36.0,
#  25.5,
#  33.5,
#  20.5,
#  30.5,
#  21.5,
#  43.1,
#  36.1,
#  32.8,
#  39.4,
#  19.9,
#  19.4,
#  20.2,
#  19.2,
#  25.1,
#  20.6,
#  20.8,
#  18.6,
#  18.1,
#  17.7,
#  27.5,
#  27.2,
#  30.9,
#  21.1,
#  23.2,
#  23.8,
#  23.9,
#  20.3,
#  21.6,
#  16.2,
#  19.8,
#  22.3,
#  17.6,
#  18.2,
#  16.9,
#  31.9,
#  34.1,
#  35.7,
#  27.4,
#  25.4,
#  34.2,
#  34.5,
#  31.8,
#  37.3,
#  28.4,
#  28.8,
#  26.8,
#  41.5,
#  38.1,
#  32.1,
#  37.2,
#  26.4,
#  24.3,
#  19.1,
#  34.3,
#  29.8,
#  31.3,
#  37.0,
#  32.2,
#  46.6,
#  27.9,
#  40.8,
#  44.3,
#  43.4,
#  36.4,
#  44.6,
#  40.9,
#  33.8,
#  32.7,
#  23.7,
#  23.6,
#  32.4,
#  26.6,
#  25.8,
#  23.5,
#  39.1,
#  39.0,
#  35.1,
#  32.3,
#  37.7,
#  34.7,
#  34.4,
#  29.9,
#  33.7,
#  32.9,
#  31.6,
#  28.1,
#  30.7,
#  24.2,
#  22.4,
#  34.0,
#  38.0,
#  44.0]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hp_per_weight'] = df['horsepower'] / df['weight']
df.set_index('hp_per_weight', inplace=True)

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
df.loc[df['horsepower'].idxmax()]
# Out:
# mpg              16.0
# cylinders           8
# displacement    400.0
# horsepower      230.0
# weight           4278
# acceleration      9.5
# model_year         73
# origin            usa
# Name: 0.053763440860215055, dtype: object

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
(df['mpg'] >= 35).sum()
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
df_filtered = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
df_filtered['origin'].mode()[0]
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
df.groupby('model_year')['mpg'].mean().idxmax()
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
median_mpg = df['mpg'].median()
df_filtered = df[df['mpg'] > median_mpg].copy()
df_filtered['hp_to_weight'] = df_filtered['horsepower'] / df_filtered['weight']
df_filtered[df_filtered['hp_to_weight'] == df_filtered['hp_to_weight'].max()]
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.050582       26.0          4         121.0       113.0    2234
#
#                acceleration  model_year  origin  hp_to_weight
# hp_per_weight
# 0.050582               12.5          70  europe      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
import seaborn as sns
import matplotlib.pyplot as plt

avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
df = df.reset_index(drop=True)

sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    palette='deep',
    hue_order=['japan', 'europe', 'usa']
)
plt.title('Horsepower vs Weight by Origin')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin')
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
print("Available columns:", df.columns.tolist())

# Then use a column that exists in the dataframe
# For this example, let's assume 'car' might be the correct column name
if 'car_name' in df.columns:
    column_to_use = 'car_name'
elif 'name' in df.columns:
    column_to_use = 'name'
elif 'car' in df.columns:  # Adding another potential column name
    column_to_use = 'car'
else:
    # Print an error message if none of the expected columns exist
    print("Error: Required columns not found in the dataframe")
    # You might want to inspect the first few rows to see what's available
    print(df.head())
    # Use a column that definitely exists to avoid the error
    column_to_use = df.columns[0]  # Using the first column as a fallback

grouped = df.groupby(column_to_use).agg(
    mpg_std=('mpg', 'std'),
    mpg_mean=('mpg', 'mean'),
    count=('model_year', 'count')
).reset_index()

consistent = grouped[(grouped['count'] >= 2) & (grouped['mpg_std'] < 1.0)]
consistent_sorted = consistent.sort_values(by=['count', 'mpg_mean'], ascending=[False, False])
consistent_sorted
# Out:
# Available columns: ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin']
# Error: Required columns not found in the dataframe
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa
#       mpg  mpg_std  mpg_mean  count
# 4    13.0      0.0      13.0     20
# 5    14.0      0.0      14.0     19
# 17   18.0      0.0      18.0     17
# 7    15.0      0.0      15.0     16
# 58   26.0      0.0      26.0     14
# 9    16.0      0.0      16.0     13
# 22   19.0      0.0      19.0     12
# 53   25.0      0.0      25.0     11
# 49   24.0      0.0      24.0     11
# 68   28.0      0.0      28.0     10
# 42   23.0      0.0      23.0     10
# 38   22.0      0.0      22.0     10
# 63   27.0      0.0      27.0      9
# 28   20.0      0.0      20.0      9
# 72   29.0      0.0      29.0      8
# 34   21.0      0.0      21.0      8
# 80   31.0      0.0      31.0      7
# 76   30.0      0.0      30.0      7
# 13   17.0      0.0      17.0      7
# 108  36.0      0.0      36.0      6
# 86   32.0      0.0      32.0      6
# 3    12.0      0.0      12.0      6
# 14   17.5      0.0      17.5      5
# 8    15.5      0.0      15.5      5
# 115  38.0      0.0      38.0      4
# 29   20.2      0.0      20.2      4
# 2    11.0      0.0      11.0      4
# 111  37.0      0.0      37.0      3
# 95   33.5      0.0      33.5      3
# 94   33.0      0.0      33.0      3
# 64   27.2      0.0      27.2      3
# 36   21.5      0.0      21.5      3
# 31   20.5      0.0      20.5      3
# 24   19.2      0.0      19.2      3
# 20   18.5      0.0      18.5      3
# 11   16.5      0.0      16.5      3
# 109  36.1      0.0      36.1      2
# 105  35.0      0.0      35.0      2
# 103  34.5      0.0      34.5      2
# 99   34.1      0.0      34.1      2
# 98   34.0      0.0      34.0      2
# 90   32.4      0.0      32.4      2
# 82   31.5      0.0      31.5      2
# 77   30.5      0.0      30.5      2
# 74   29.8      0.0      29.8      2
# 73   29.5      0.0      29.5      2
# 61   26.6      0.0      26.6      2
# 56   25.5      0.0      25.5      2
# 55   25.4      0.0      25.4      2
# 52   24.5      0.0      24.5      2
# 48   23.9      0.0      23.9      2
# 32   20.6      0.0      20.6      2
# 25   19.4      0.0      19.4      2
# 18   18.1      0.0      18.1      2
# 15   17.6      0.0      17.6      2
# 1    10.0      0.0      10.0      2

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
